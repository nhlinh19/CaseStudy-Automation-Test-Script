# %%
import requests
import json

# %%
url = "http://localhost/web/index.php/api/v2/admin/users"
url_emp = "http://localhost/web/index.php/api/v2/pim/employees"
s = requests.Session()

def set_data(username,password,status,userRoleId,empNumber):
    data = {
        "username":username,
        "password":password,
        "status":status,
        "userRoleId":int(userRoleId),
        "empNumber":int(empNumber)
    }
    return data
cookie = '_orangehrm=cd92da8d7849e66b497be436c197b0fa; _xsrf=2|85abd783|af3f999a057fff742d325fa5e9e63c76|1669463325; username-localhost-8888="2|1:0|10:1669466910|23:username-localhost-8888|44:YjRkMGIzYTNkYTgyNGU1MmIwZjY0NTA5ZDM1Nzk3YjE=|a3f34a805240703991dc5dbd775bd732690c4302415059a1b98aa355a292c793"'
def set_header(cookie):
    return {
        "Content-Type":"application/json",
        "Accept": "application/json, text/plain, */*",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
        "Referer": "http://localhost/web/index.php/pim/addEmployee",
        "Cookie": cookie,
        "Connection": "keep-alive",
        "Host": "localhost",
        "Origin": "http://localhost",
    }
def set_header_emp(cookie):
    return {
        "Content-Type":"application/json",
        "Accept": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
        "Referer": "http://localhost/web/index.php/pim/addEmployee",
        "Cookie": cookie,
        "Connection": "keep-alive",
        "Host": "localhost",
        "Origin": "http://localhost",
    }
def set_data_emp(firstName,lastName,employeeId):
    return {
    "firstName": firstName,
    "middleName": "",
    "lastName": lastName,
    "empPicture": None,
    "employeeId": str(employeeId)
}
init_id = 511
for i in range(500):
    # data = set_data("test"+str(i),"P@ssw0rd",True,2,init_id)
    data_emp = set_data_emp("test"+str(i),"test"+str(i),init_id)
    # print(data_emp)
    # print(data)
    header = set_header(cookie)
    header_emp = set_header_emp(cookie)
    response_emp = s.post(url_emp,headers=header_emp,data=json.dumps(data_emp))
    # response = s.post(url,headers=header,data=json.dumps(data))
    init_id += 1
    print(response_emp.status_code)
    # print(response.status_code)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
init_id=511
for i in range(500):
    data = set_data("test"+str(init_id),"P@ssw0rd",True,2,init_id)
    # print(data)
    header = set_header(cookie)
    response = s.post(url,headers=header,data=json.dumps(data))
    init_id += 1
    print(response.status_code)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
{
    "username": "temp7",
    "password": "P@ssw0rd",
    "status": true,
    "userRoleId": 2,
    "empNumber": 6
}

# %%
{
    "firstName": "temp2",
    "middleName": "",
    "lastName": "temp2",
    "empPicture": null,
    "employeeId": "0008"
}
